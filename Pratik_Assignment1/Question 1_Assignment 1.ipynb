# %%
l = []
n = int(input("Enter the number of integers"))
for i in range(0,n):
    l.append(int(input()))
max = min = l[0]
for i in range(n):
    if(l[i]>max): max = l[i]
    if(l[i]<min): min = l[i]
print(max, min)
# Out:
# Enter the number of integers 5
#  5
#  2
#  1
#  4
#  3
# 5 1
