# %%
l = [1,3,5,2,61,12,46,42,26,7,96,43,73,75,32]
x = 19
found = False
for i in l:
    for j in l:
        if(abs(j-i)==x):
            print(i, j)
            found=True
            break
    if(found): break
# Out:
# 61 42
