# %%
import numpy as np
def q1(array):
    a = array[0]
    b = array[0]
    for i in array:
        if i > a:
            a = i
        if i < b:
            b = i
    print("The maximum value in the matrix is ", a)
    print("The minimum value in the matrix is ", b)
def q2(word):
    word = input("Enter the string you want to check: ")
    for i in range(0,len(word)):
        if word[i]!= word[len(word)-i-1]:
            print("Not a palindrome")
            break
        if i == (len(word)-1):
            print("Yes, its a palindrome")xss
def q3(array2,x):
    np.sort(array2)
    for i in range(0,len(array2)):
        a = array2[i]
        for j in range(i+1,len(array2)):
            b = array2[j]
            if (b-a)==x:
                print(b ," and ", a)
def q4(array3,a,b,c):
    l1=[]
    l2=[]
    l3=[]
    for i in array3:
        if i == min(a,b,c):
            l1.append(i)
        elif i == a+b+c-max(a,b,c)-min(a,b,c):
            l2.append(i)
        else:
            l3.append(i)
    print(np.array(l1+l2+l3))
q1([1,2,3,4,3])
q2("")
q3([2,4,5,7],2)
q4([2,3,3,4,2,4,3],3,2,4)
